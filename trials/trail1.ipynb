# %%
import os 
import zipfile
import tarfile
from six.moves import urllib

# %%
download_url = 'https://www.kaggle.com/datasets/elikplim/concrete-compressive-strength-data-set/download?datasetVersionNumber=1'

# %%
os.getcwd()
# Out:
# '/home/yash/project/ineuron_internship_projects/ML-project-internship/trials'

# %%
download_path = os.path.join("Data","Concrete")
os.makedirs(download_path,exist_ok=True)
zip_path = os.path.join(download_path,"archive.tar.gz")
urllib.request.urlretrieve(download_url,zip_path)
with tarfile.open(zip_path) as tf:
    tf.extractall(zip_path)
    tf.close()
# Out:
# ---------------------------------------------------------------------------
# ReadError                                 Traceback (most recent call last)
# /tmp/ipykernel_271239/1105087310.py in <module>
#       3 zip_path = os.path.join(download_path,"archive.tar.gz")
#       4 urllib.request.urlretrieve(download_url,zip_path)
# ----> 5 with tarfile.open(zip_path) as tf:
#       6     tf.extractall(zip_path)
#       7     tf.close()
#
# ~/project/ineuron_internship_projects/ML-project-internship/venv/lib/python3.7/tarfile.py in open(cls, name, mode, fileobj, bufsize, **kwargs)
#    1574                         fileobj.seek(saved_pos)
#    1575                     continue
# -> 1576             raise ReadError("file could not be opened successfully")
#    1577
#    1578         elif ":" in mode:
#
# ReadError: file could not be opened successfully

# %%
download_path = os.path.join("dataset","strength")

# %%
def fetch_strength_data(download_url=download_url,download_path=download_path):
    if not os.path.isdir(download_path,"archive.zip"):
        os.makedirs(download_path)
    zip_path = os.path.join(download_path,"archive.zip")
    urllib.request.urlretrieve(download_url,zip_path)
    with zipfile.ZipFile(zip_path, "r") as zip_ref:
        zip_ref.extractall(path = zip_path)
        zip_ref.close()

# %%
! pip install numpy pandas matplotlib seaborn
# Out:
# ...
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# ...
#   Using cached pandas-1.1.5-cp37-cp37m-manylinux1_x86_64.whl (9.5 MB)
# ...
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# ...
#   Using cached seaborn-0.12.0-py3-none-any.whl (285 kB)
# ...
#   Using cached pytz-2022.4-py2.py3-none-any.whl (500 kB)
# ...
#   Using cached kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#   Using cached Pillow-9.2.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.2 MB)
# ...
#   Using cached fonttools-4.37.4-py3-none-any.whl (960 kB)
# ...

# %%
import pandas as pd

def load_strength_data(download_path=download_path):
    xls_path = os.path.join(download_path,"ConcreteCompressiveStrength.xls")
    return pd.read_excel(xls_path)

# %%
pd.read_excel(xls_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_258248/1111208167.py in <module>
# ----> 1 pd.read_excel(xls_path)
#
# NameError: name 'xls_path' is not defined

# %%
! pip install xlrd
# Out:
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...

# %%
import os
import zipfile
from six.moves import urllib
import pandas as pd

# %%
download_url = 'https://archive.ics.uci.edu/ml/machine-learning-databases/concrete/compressive/Concrete_Data.xls'
download_path = os.path.join("dataset","strength")
os.makedirs(download_path,exist_ok=True)
zip_file_path = os.path.join(download_path,"Concrete_Data.xls")
urllib.request.urlretrieve(download_url,zip_file_path)
# with zipfile.ZipFile(zip_file_path,"r") as zip_ref:
#     zip_ref.extractall(path = zip_file_path)
#     zip.close()
df = pd.read_excel(zip_file_path)

# %%
csv_path = os.makedirs("csv_path", exist_ok=True)
save_path = os.getcwd()+"/csv_path/Concrete_Data.csv"
# df.to_csv( "Concrete_Data.csv",index=None, header=True, encoding = 'utf-8')
df.to_csv(save_path)

# %%
import shutil
# archive = os.makedirs("archive",exist_ok=True)
zip = shutil.make_archive('Concrete_Data', 'zip', os.getcwd()+"/csv_path")
# os.path.join(zip,archive)

# %%
zf_conv = df.to_csv(df,compression='gzip')
dir = os.makedirs('zipfile',exist_ok=True)
os.path.join(zf_conv,dir)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6443/1840463100.py in <module>
# ----> 1 zf_conv = df.to_csv(df,compression='gzip')
#       2 dir = os.makedirs('zipfile',exist_ok=True)
#       3 os.path.join(zf_conv,dir)
#
# ~/project/ineuron_internship_projects/ML-project-internship/venv/lib/python3.7/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3166             doublequote=doublequote,
#    3167             escapechar=escapechar,
# -> 3168             decimal=decimal,
#    3169         )
#    3170         formatter.save()
#
# ...

# %%
pd.read_csv(save_path)
# Out:
#       Unnamed: 0  Cement (component 1)(kg in a m^3 mixture)  \
# 0              0                                      540.0
# 1              1                                      540.0
# 2              2                                      332.5
# 3              3                                      332.5
# 4              4                                      198.6
# ...          ...                                        ...
# 1025        1025                                      276.4
# 1026        1026                                      322.2
# 1027        1027                                      148.5
# 1028        1028                                      159.1
# 1029        1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# ...

# %%
os.remove(zip_file_path)

# %%
df1 = pd.DataFrame(df)

# %%
display(df1)
# Out:
#       Cement (component 1)(kg in a m^3 mixture)  \
# 0                                         540.0
# 1                                         540.0
# 2                                         332.5
# 3                                         332.5
# 4                                         198.6
# ...                                         ...
# 1025                                      276.4
# 1026                                      322.2
# 1027                                      148.5
# 1028                                      159.1
# 1029                                      260.9
#
#       Blast Furnace Slag (component 2)(kg in a m^3 mixture)  \
# 0                                                   0.0
# 1                                                   0.0
# 2                                                 142.5
# 3                                                 142.5
# 4                                                 132.4
# ...

# %%
dict = {'Cement (component 1)(kg in a m^3 mixture)':'Cement',
       'Blast Furnace Slag (component 2)(kg in a m^3 mixture)':'Blast_Furnace_Slag',
       'Fly Ash (component 3)(kg in a m^3 mixture)':'Fly_Ash ',
       'Water  (component 4)(kg in a m^3 mixture)':'Water',
       'Superplasticizer (component 5)(kg in a m^3 mixture)':'Superplasticizer',
       'Coarse Aggregate  (component 6)(kg in a m^3 mixture)':'Coarse_Aggregate  ',
       'Fine Aggregate (component 7)(kg in a m^3 mixture)':'Fine_Aggregate', 
       'Age (day)':'Age ',
       'Concrete compressive strength(MPa, megapascals) ':'Concrete_compressive_strength'}

# %%
df1.rename(columns=dict, inplace=True)

# %%
df1.to_csv('Concrete_Data.csv',index=False)

# %%
display(df1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_135744/3251320122.py in <module>
# ----> 1 display(df1)
#
# NameError: name 'df1' is not defined

# %%
Df= pd.read_csv("/home/yash/project/ineuron_internship_projects/ML-project-internship/trials/Concrete_Data.csv")
Df
# Out:
#       Cement  Blast_Furnace_Slag  Fly_Ash   Water  Superplasticizer  \
# 0      540.0                 0.0       0.0  162.0               2.5
# 1      540.0                 0.0       0.0  162.0               2.5
# 2      332.5               142.5       0.0  228.0               0.0
# 3      332.5               142.5       0.0  228.0               0.0
# 4      198.6               132.4       0.0  192.0               0.0
# ...      ...                 ...       ...    ...               ...
# 1025   276.4               116.0      90.3  179.6               8.9
# 1026   322.2                 0.0     115.6  196.0              10.4
# 1027   148.5               139.4     108.6  192.7               6.1
# 1028   159.1               186.7       0.0  175.6              11.3
# 1029   260.9               100.5      78.3  200.6               8.6
#
#       Coarse_Aggregate    Fine_Aggregate  Age   Concrete_compressive_strength
# ...

# %%
Df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Cement                         1030 non-null   float64
#  1   Blast_Furnace_Slag             1030 non-null   float64
#  2   Fly_Ash                        1030 non-null   float64
#  3   Water                          1030 non-null   float64
#  4   Superplasticizer               1030 non-null   float64
#  5   Coarse_Aggregate               1030 non-null   float64
#  6   Fine_Aggregate                 1030 non-null   float64
#  7   Age                            1030 non-null   int64
#  8   Concrete_compressive_strength  1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %%
df1.columns
# Out:
# Index(['Cement', 'Blast_Furnace_Slag', 'Fly_Ash ', 'Water', 'Superplasticizer',
#        'Coarse_Aggregate  ', 'Fine_Aggregate', 'Age ',
#        'Concrete_compressive_strength'],
#       dtype='object')

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_95740/3309751900.py in <module>
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
# convert csv file in zip file

# %% [markdown]
# ### Cassandra DataBase Operation

# %%
from cassandra.auth import PlainTextAuthProvider
from cassandra.cluster import Cluster

# %%
import pandas as pd
import csv

# %%
# assigning variables

keyspace = 'concrete'

table_name = 'Concrete_Data'

client_id = "nMFQjAUuIlzDlWwTUMoHpyLt"

client_secret = "WcQyxvM+KnQ.FofHk7hmj+rq_8hhMXk9lAZIxaS71FuFufpkg6.yYJL,aAuEQqF_Zjw,_kUFsPPkTbH2ng.GLoaHEe,S9DoObNpy416ktSB6w3XY2um6Hzd16uGIRJL6"

cloud_config = {
    'secure_connect_bundle':r'/home/yash/project/ineuron_internship_projects/ML-project-internship/secure-connect-concrete-data.zip'
}

# %%
auth_provider = PlainTextAuthProvider(client_id, client_secret)

# %%
cluster =  Cluster(cloud=cloud_config, auth_provider=auth_provider)

# %%
session = cluster.connect()

# %%
file = "/home/yash/project/ineuron_internship_projects/ML-project-internship/trials/Concrete_Data.csv"

# %%
# create Table
session.execute("USE {keyspace};".format(keyspace=keyspace))

# %%
# Create Table
session.execute('CREATE TABLE {table_name} (Cement float PRIMARY KEY, Blast_Furnace_Slag float, Fly_Ash float, Water float, Superplasticizer float, Coarse_Aggregate float, Fine_Aggregate float, Age int, Concrete_compressive_strength float);'.format(table_name=table_name))

# %%
# Insert Data Into Table from CSV to Database TABLE

with open(file, mode='r') as f:
    next(f)
    reader = csv.reader(f, delimiter='\n')
    for i in reader:
        data = ','.join([value for value in i])

        session.execute("USE {keyspace};".format(keyspace=keyspace))

        session.execute('INSERT INTO {table_name} (Cement , Blast_Furnace_Slag , Fly_Ash , Water, Superplasticizer, Coarse_Aggregate, Fine_Aggregate, Age , Concrete_compressive_strength) VALUES ({data});'.format(table_name=table_name, data=data))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_63391/637026139.py in <module>
#       7         data = ','.join([value for value in i])
#       8
# ----> 9         session.execute("USE {keyspace};".format(keyspace=keyspace))
#      10
#      11         session.execute('INSERT INTO {table_name} (Cement , Blast_Furnace_Slag , Fly_Ash , Water, Superplasticizer, Coarse_Aggregate, Fine_Aggregate, Age , Concrete_compressive_strength) VALUES ({data});'.format(table_name=table_name, data=data))
#
# ~/project/ineuron_internship_projects/ML-project-internship/venv/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.Session.execute()
#
# ~/project/ineuron_internship_projects/ML-project-internship/venv/lib/python3.7/site-packages/cassandra/cluster.cpython-37m-x86_64-linux-gnu.so in cassandra.cluster.ResponseFuture.result()
#
# ...

# %%
# session.execute("DROP  TABLE Concrete_Data;")

# %%
# Get Data From DataBase

df = pd.DataFrame()

# %%
# Query

query = "SELECT * FROM {keyspace}.{table_name};".format(keyspace=keyspace,table_name=table_name)

# %%
for row in session.execute(query):
    df = df.append(pd.DataFrame([row]))

# %%
df
# Out:
#         cement  age  blast_furnace_slag  coarse_aggregate  \
# 0   142.000000   28          167.000000        883.000000
# 0   155.000000   28            0.000000        877.000000
# 0   153.600006   28          144.199997        923.200012
# 0   339.000000   28            0.000000       1060.000000
# 0   122.599998    7          183.899994        958.200012
# ..         ...  ...                 ...               ...
# 0   266.200012   28          112.300003        909.700012
# 0   355.000000   28           19.000000        967.000000
# 0   144.800003   28            0.000000        979.500000
# 0   133.100006   28          210.199997        949.400024
# 0   491.000000   56           26.000000        822.000000
#
#     concrete_compressive_strength  fine_aggregate     fly_ash  \
# 0                       44.609097      785.000000  130.000000
# 0                        9.735401      868.000000  143.000000
# 0                       16.503986      657.900024  112.300003
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 280 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cement                         280 non-null    float64
#  1   age                            280 non-null    int64
#  2   blast_furnace_slag             280 non-null    float64
#  3   coarse_aggregate               280 non-null    float64
#  4   concrete_compressive_strength  280 non-null    float64
#  5   fine_aggregate                 280 non-null    float64
#  6   fly_ash                        280 non-null    float64
#  7   superplasticizer               280 non-null    float64
#  8   water                          280 non-null    float64
# dtypes: float64(8), int64(1)
# memory usage: 21.9 KB
